# %%
import numpy as np
import pandas as pd
import seaborn as sns     

import matplotlib.pyplot as plt   
import matplotlib as mpl          
mpl.rc('font', family='Malgun Gothic')     
plt.rcParams['axes.unicode_minus']=False


from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import FinanceDataReader as fdr
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.statespace.sarimax import SARIMAX

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # 주식 예측

# %% [markdown]
# ## 기본 작업

# %%
stock=fdr.DataReader('005930', start='2024-01-01')    # 삼성전자 
stock.shape
# Out:
# (308, 6)

# %%
stock.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2025-04-02  58800  59400  58300  58800  14402297  0.000000
# 2025-04-03  56900  57800  56900  57600  19508076 -0.020408
# 2025-04-04  56200  58200  55700  56100  23527139 -0.026042
# 2025-04-07  53300  54100  53100  53200  31998883 -0.051693
# 2025-04-08  55000  55300  53300  53500  23531182  0.005639

# %% [markdown]
# - 결측치
#     - 선형 보간법 : 날짜기 비어 있는 부분을 보간
#     - 'D'=일별, 'B'=영업일 기준, 'W'=주별, 'M'=월별

# %%
stock=stock.asfreq('B', method='pad')    
stock.shape
# Out:
# (331, 6)

# %%
sa_stock=stock.copy()

# %%
# 설명(독립)변수 X, 목표(종속)변수 Y
X=sa_stock[['Open', 'High', 'Low']] 
Y=sa_stock['Close']
X.shape, Y.shape
# Out:
# ((331, 3), (331,))

# %%
# 스케일 조절 - 표준화
scaler=StandardScaler()
X_scaler=scaler.fit_transform(X)

# %%
# 훈련 셋
X_train, X_test, Y_train, Y_test=train_test_split(X_scaler, Y, test_size=0.05, shuffle=False)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((314, 3), (17, 3), (314,), (17,))

# %% [markdown]
# ### 정상성 확인

# %%
fig, ax=plt.subplots(1, 2, figsize=(10, 5))
plot_acf(Y_train, lags=30, ax=ax[0])
plot_pacf(Y_train, lags=30, ax=ax[1])
plt.show()

# %%
result=adfuller(Y_train)
result
print("p-value:", result[1])
# Out:
# p-value: 0.7905156219952703

# %%
diff_Y_train=Y_train.copy()
diff_Y_train=Y_train.diff()
diff_Y_train.dropna(inplace=True)

# %%
fig, ax=plt.subplots(1, 2, figsize=(10, 5))
plot_acf(diff_Y_train.values, lags=30, ax=ax[0])         # ACF 플롯
plot_pacf(diff_Y_train.values, lags=30, ax=ax[1])        # PACF 플롯
plt.show()

# %% [markdown]
# ### SARIMAX 모델 학습

# %%
model=SARIMAX(Y_train, exog=X_train, order=(1, 1, 0))   
model_fit=model.fit()

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  314
# Model:               SARIMAX(1, 1, 0)   Log Likelihood               -2385.400
# Date:                Tue, 08 Apr 2025   AIC                           4780.800
# Time:                        21:40:11   BIC                           4799.531
# Sample:                    01-02-2024   HQIC                          4788.286
#                          - 03-14-2025
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1         -7384.4372    364.536    -20.257      0.000   -8098.915   -6669.960
# x2          9807.7571    420.958     23.299      0.000    8982.695    1.06e+04
# x3          8259.8438    498.967     16.554      0.000    7281.886    9237.801
# ar.L1         -0.1652      0.014    -11.893      0.000      -0.192      -0.138
# sigma2      2.224e+05   1.79e+04     12.420      0.000    1.87e+05    2.57e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  26.80   Jarque-Bera (JB):                 0.04
# Prob(Q):                              0.00   Prob(JB):                         0.98
# Heteroskedasticity (H):               1.20   Skew:                             0.03
# Prob(H) (two-sided):                  0.35   Kurtosis:                         2.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### 평가 및 예측
# - start=Y_test.index[0]: 예측 시작점 (테스트 데이터의 첫 번째 인덱스)
# - end=Y_test.index[-1]: 예측 종료점 (테스트 데이터의 마지막 인덱스)
# - exog=X_test: 외생 변수(설명 변수) 제공

# %%
pred=model_fit.predict(start=Y_test.index[0], end=Y_test.index[-1], exog=X_test)
pred[-5:].astype(int)
# Out:
# 2025-04-02    58631
# 2025-04-03    57421
# 2025-04-04    57336
# 2025-04-07    53675
# 2025-04-08    53761
# Freq: B, Name: predicted_mean, dtype: int32

# %%
Y_test.tail()
# Out:
# Date
# 2025-04-02    58800
# 2025-04-03    57600
# 2025-04-04    56100
# 2025-04-07    53200
# 2025-04-08    53500
# Freq: B, Name: Close, dtype: int64

# %%
r2_score(Y_test, pred)          # 평가 - 정확도
# Out:
# 0.9586979231783603

# %%
# 시각화
plt.figure(figsize=(10, 6))
plt.plot(Y_test.index, Y_test, label='Actual')     # 실제값
plt.plot(Y_test.index, pred, label='Predicted')    # 예측값
plt.title('Stock Price Prediction using SARIMAX')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## LinearRegression

# %%
lr_stock=stock.copy()
lr_stock.shape
# Out:
# (331, 6)

# %%
lr_stock.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2024-01-02  78200  79800  78200  79600  17142847  0.014013
# 2024-01-03  78500  78800  77000  77000  21753644 -0.032663
# 2024-01-04  76100  77300  76100  76600  15324439 -0.005195
# 2024-01-05  76700  77100  76400  76600  11304316  0.000000
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305

# %% [markdown]
# ### 전처리
# - 차분, 표준화

# %%
lr_stock['Close_diff']=lr_stock['Close'].diff()
lr_stock.head()
# Out:
#              Open   High    Low  Close    Volume    Change  Close_diff
# Date
# 2024-01-02  78200  79800  78200  79600  17142847  0.014013         NaN
# 2024-01-03  78500  78800  77000  77000  21753644 -0.032663     -2600.0
# 2024-01-04  76100  77300  76100  76600  15324439 -0.005195      -400.0
# 2024-01-05  76700  77100  76400  76600  11304316  0.000000         0.0
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305      -100.0

# %%
lr_stock.dropna(inplace=True)
lr_stock.head()
# Out:
#              Open   High    Low  Close    Volume    Change  Close_diff
# Date
# 2024-01-03  78500  78800  77000  77000  21753644 -0.032663     -2600.0
# 2024-01-04  76100  77300  76100  76600  15324439 -0.005195      -400.0
# 2024-01-05  76700  77100  76400  76600  11304316  0.000000         0.0
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305      -100.0
# 2024-01-09  77400  77700  74300  74700  26019249 -0.023529     -1800.0

# %%
lr_stock['Next_Close_diff']=lr_stock['Close_diff'].shift(-1)
lr_stock.head()
# Out:
#              Open   High    Low  Close    Volume    Change  Close_diff  \
# Date
# 2024-01-03  78500  78800  77000  77000  21753644 -0.032663     -2600.0
# 2024-01-04  76100  77300  76100  76600  15324439 -0.005195      -400.0
# 2024-01-05  76700  77100  76400  76600  11304316  0.000000         0.0
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305      -100.0
# 2024-01-09  77400  77700  74300  74700  26019249 -0.023529     -1800.0
#
#             Next_Close_diff
# Date
# 2024-01-03           -400.0
# 2024-01-04              0.0
# 2024-01-05           -100.0
# 2024-01-08          -1800.0
# 2024-01-09          -1100.0

# %%
lr_stock.tail()
# Out:
#              Open   High    Low  Close    Volume    Change  Close_diff  \
# Date
# 2025-04-02  58800  59400  58300  58800  14402297  0.000000         0.0
# 2025-04-03  56900  57800  56900  57600  19508076 -0.020408     -1200.0
# 2025-04-04  56200  58200  55700  56100  23527139 -0.026042     -1500.0
# 2025-04-07  53300  54100  53100  53200  31998883 -0.051693     -2900.0
# 2025-04-08  55000  55300  53300  53500  23531182  0.005639       300.0
#
#             Next_Close_diff
# Date
# 2025-04-02          -1200.0
# 2025-04-03          -1500.0
# 2025-04-04          -2900.0
# 2025-04-07            300.0
# 2025-04-08              NaN

# %%
lr_stock.dropna(inplace=True)

# %%
X=lr_stock[['Open', 'High', 'Low', 'Close_diff']]
Y=lr_stock['Next_Close_diff']

X.shape, Y.shape
# Out:
# ((329, 4), (329,))

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_scaled.shape
# Out:
# (329, 4)

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X_scaled, Y, test_size=0.05, random_state=42, shuffle=False)
X_train.shape, X_test.shape
# Out:
# ((312, 4), (17, 4))

# %% [markdown]
# ### 모델 학습

# %%
lr_model=LinearRegression()
lr_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(X_train, Y_train), lr_model.score(X_test, Y_test)
# Out:
# (0.006525663038626561, 0.01418667995068823)

# %% [markdown]
# ### 모델 학습

# %%
rf_model=RandomForestRegressor(n_estimators=50, max_depth=5, random_state=42)
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=50, random_state=42)

# %%
rf_model.score(X_train, Y_train), rf_model.score(X_test, Y_test)
# Out:
# (0.2747637675565786, -0.028258857920641978)

# %% [markdown]
# ## RandomForestRegressor
# ### 학습 및 전처리

# %%
rf_stock=stock.copy()

# %%
rf_stock.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Change'], dtype='object')

# %%
X=rf_stock[['Open', 'High', 'Low', 'Close']]
Y=rf_stock['Close'].shift(-1)

# %%
X=X[:-1]       # 마지막 행 삭제 (Y에서 NaN을 제거한 후 X에도 적용)
Y=Y.dropna()   # Y에서 NaN 제거

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=0.2, shuffle=False)
X_train.shape, Y_train.shape
# Out:
# ((264, 4), (264,))

# %%
rf_model=RandomForestRegressor(n_estimators=50, max_depth=5, random_state=42)
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=50, random_state=42)

# %%
rf_model.score(X_train, Y_train), rf_model.score(X_test, Y_test)
# Out:
# (0.9905220277592444, 0.7928513496877363)

# %%
rf_pred=rf_model.predict(X_test)

# %%
plt.figure(figsize=(12, 6))
plt.plot(Y_test.values, label='Actual', color='black')
plt.plot(rf_pred, label='Random Forest', color='red', linestyle='dashed')
plt.legend()
plt.title("Samsung Stock Price Prediction (Differenced)")
plt.show()

# %%
tomorrow_features=X_test[-1:]  # X_test의 마지막 행 가져오기
tomorrow_prediction=rf_model.predict(tomorrow_features)
tomorrow_prediction
# Out:
# array([53564.57840898])

# %%
tomorrow_features
# Out:
#              Open   High    Low  Close
# Date
# 2025-04-07  53300  54100  53100  53200

# %% [markdown]
# ### 평균 이동

# %%
avg_stock=stock.copy()
avg_stock.shape
# Out:
# (331, 6)

# %% [markdown]
# - 20개의 데이터 포인트를 기준으로 이동 평균을 계산

# %%
avg_stock['SAM_20']=avg_stock['Close'].rolling(window=20).mean()      # 20일 이동평균
avg_stock.head(21)
# Out:
#              Open   High    Low  Close    Volume    Change   SAM_20
# Date
# 2024-01-02  78200  79800  78200  79600  17142847  0.014013      NaN
# 2024-01-03  78500  78800  77000  77000  21753644 -0.032663      NaN
# 2024-01-04  76100  77300  76100  76600  15324439 -0.005195      NaN
# 2024-01-05  76700  77100  76400  76600  11304316  0.000000      NaN
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305      NaN
# 2024-01-09  77400  77700  74300  74700  26019249 -0.023529      NaN
# 2024-01-10  75000  75200  73200  73600  20259529 -0.014726      NaN
# 2024-01-11  72900  73600  72700  73200  57691266 -0.005435      NaN
# 2024-01-12  73000  74100  72800  73100  13038939 -0.001366      NaN
# 2024-01-15  73200  74000  73200  73900  13212339  0.010944      NaN
# 2024-01-16  73500  73700  72500  72600  14760415 -0.017591      NaN
# 2024-01-17  73100  73300  71000  71000  22683660 -0.022039      NaN
# 2024-01-18  71600  72000  70700  71700  17853397  0.009859      NaN
# 2024-01-19  73500  74700  73000  74700  23363427  0.041841      NaN
# 2024-01-22  75900  76000  75000  75100  19673375  0.005355      NaN
# 2024-01-23  75700  75800  74300  75200  14786224  0.001332      NaN
# 2024-01-24  75200  75200  73500  74000  12860661 -0.015957      NaN
# 2024-01-25  74200  74800  73700  74100  11737747  0.001351      NaN
# 2024-01-26  73700  74500  73300  73400  11160062 -0.009447      NaN
# 2024-01-29  73800  75200  73500  74400  13976521  0.013624  74550.0
# 2024-01-30  75000  75300  73700  74300  12244418 -0.001344  74285.0

# %%
avg_stock.dropna(inplace=True)
# avg_stock.isnull().sum()

# %%
avg_stock.head()
# Out:
#              Open   High    Low  Close    Volume    Change   SAM_20
# Date
# 2024-01-29  73800  75200  73500  74400  13976521  0.013624  74550.0
# 2024-01-30  75000  75300  73700  74300  12244418 -0.001344  74285.0
# 2024-01-31  73400  74000  72500  72700  15703560 -0.021534  74070.0
# 2024-02-01  73000  74200  72900  73600  19881033  0.012380  73920.0
# 2024-02-02  74000  75200  73700  75200  14955881  0.021739  73850.0

# %%
X=avg_stock[['SAM_20']]
X.shape
# Out:
# (312, 1)

# %%
Y=avg_stock['Close'].shift(-1)       # 다음날의 종가를 예측
Y.tail()
# Out:
# Date
# 2025-04-02    57600.0
# 2025-04-03    56100.0
# 2025-04-04    53200.0
# 2025-04-07    53500.0
# 2025-04-08        NaN
# Freq: B, Name: Close, dtype: float64

# %%
X=X[:-1]       
Y=Y.dropna()

# %% [markdown]
# #### 학습 및 평가

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=0.2, shuffle=False)
X_train.shape, X_test.shape
# Out:
# ((248, 1), (63, 1))

# %%
rf_model=RandomForestRegressor(n_estimators=50, max_depth=5)
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=50)

# %%
rf_model.score(X_train, Y_train), rf_model.score(X_test, Y_test)
# Out:
# (0.9385201450826537, -0.3809981565363929)

# %%
pred=rf_model.predict(X_test)

# %%
plt.figure(figsize=(12, 6))
plt.plot(Y_test.values, label='Actual')
plt.plot(pred, label='Random Forest', linestyle='dashed')
plt.legend()
plt.title("Samsung Stock Price Prediction (Differenced)")
plt.show()
